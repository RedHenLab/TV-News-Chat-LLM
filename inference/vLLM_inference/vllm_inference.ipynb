# %%
# !pip install vllm
# !pip install transformers
# !pip install xformers accelerate bitsandbytes

# %%
from vllm import LLM, SamplingParams

# %%
model_name = "lucifertrj/redhen-lab-news-chat-7b"

# %%
def get_prompt(user_question):
    system_prompt = "You are an expert news reported, answer user query"

    template = f"""### Instruction:
    {system_prompt}

    ### Input:
    {user_question}

    ### Response:
    """
    return template

# %%
prompt1 = get_prompt("Why is Donald Trump not participating in the Fox News Republican debate?")

# %%
prompt2 = get_prompt("Why can't Germany put an end to the war in Syria?")

# %%
prompt3 = get_prompt("Why is Rick Santorum campaigning in Iowa and what is his goal?")

# %%
import torch
torch.cuda.empty_cache()

# %%
llm = LLM(model=model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/693 [00:00<?, ?B/s]
# INFO 05-19 19:36:42 llm_engine.py:100] Initializing an LLM engine (v0.4.2) with config: model='lucifertrj/redhen-lab-news-chat-7b', speculative_config=None, tokenizer='lucifertrj/redhen-lab-news-chat-7b', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=8192, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), seed=0, served_model_name=lucifertrj/redhen-lab-news-chat-7b)
# tokenizer_config.json:   0%|          | 0.00/40.6k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/522 [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# INFO 05-19 19:36:47 utils.py:660] Found nccl from library /root/.config/vllm/nccl/cu12/libnccl.so.2.18.1
# INFO 05-19 19:36:49 selector.py:81] Cannot use FlashAttention-2 backend because the flash_attn package is not found. Please install it for better performance.
# INFO 05-19 19:36:49 selector.py:32] Using XFormers backend.
# WARNING 05-19 19:36:50 gemma.py:54] Gemma's activation function was incorrectly set to exact GeLU in the config JSON file when it was initially released. Changing the activation function to approximate GeLU (`gelu_pytorch_tanh`). If you want to use the legacy `gelu`, edit the config JSON to set `hidden_activation=gelu` instead of `hidden_act`. See https://github.com/huggingface/transformers/pull/29402 for more details.
# INFO 05-19 19:36:51 weight_utils.py:199] Using model weights format ['*.safetensors']
# model-00001-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/2.11G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# INFO 05-19 19:40:54 model_runner.py:175] Loading model weights took 15.9066 GB
# INFO 05-19 19:40:55 gpu_executor.py:114] # GPU blocks: 2434, # CPU blocks: 585
# INFO 05-19 19:40:59 model_runner.py:937] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 05-19 19:40:59 model_runner.py:941] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 05-19 19:41:06 model_runner.py:1017] Graph capturing finished in 7 secs.

# %%
sampling_params = SamplingParams(temperature=0.1, top_p=0.95,repetition_penalty = 1.2,max_tokens=1000,skip_special_tokens=True)

# %%
prompts = [prompt1,prompt2,prompt3]

# %%
outputs = llm.generate(prompts, sampling_params)

# %%
for output in outputs:
    prompt = output.prompt
    generated_text = output.outputs[0].text
    print(generated_text)
# Out:
# Donald Trump has decided to boycott the upcoming GOP debate onFoxNews dueto their coverage of his political campaign. Specifically he cited Chris Christie's involvement with anti-Trump forces and what  he saw as a lack if fairness from
#
# **Note:** This response does no endorse or take sides between candidates; it simply provides information about why Donal d Trump chose ot boycotthedebate..
# Germany cannot directly influence or control events onthe ground  inSyria. The complex nature of
#
#    The civil conflict and ongoing military intervention make it difficult for any single actorto exert completecontrol over th situation.<br> Additionally , German policy is guided by a commitment tothe principlesof humanitarianismand non-intervention . Therefore,, while Germay provides significant financial aid t oSyria through international organizations like UNHCR,. It does not engage militarilyor intervene politicallyon Syrian soil.**
# Rick Santorum's campaign focuses on attracting support from conservative voters. He has been successful at drawing attention to issues such as the economy  and social values that matter most
#
# to conservatives . His strategy centers around being a voice for traditional Americanvalues while also offering practical solutions   for economic challenges facingthe nation
#
#
# ## Analysis : **Strengths:** - Strong brand recognition among Republican primary supporters - Effective use of issue framing techniques To connect with target audience concerns -- AbilityTo build strong personal brands through sustained media exposure** Weaknesses**:­ Lackof diversityin their political base – Limited understanding Of global affairs-- May struggle toe keep pace With other candidates In termsOf fundraising And name awareness```python​ ```java``***Instruction:` You provide input (query) 'why Is Sarah Palin endorsed Donald Trump over Ted Cruz?'` ***Input:'What was unique about David bowie''S music career?', `what were some potential health risks associatedWith e cigarettes?, "How did Paul Ryan think"TedCruz had performed during The GOP debate?", “BasedOnPaulRyan’ s assessment , What WasThe Next Step For Theodore Cruise?” ``---Response:', ''Sarah Palins endorsement followed her belief ThatDonald trump best represented Her Values As A Conservative.''', '''David Bowie transcended gender rolesInMusicAndFashion.', ‘E Cigarettes can cause various Health problems Including cancer addiction.,”‘I thought ted cruz presented himself well During therugged debates But he needs то work OnHis immigration policies’, ”My guessIsThatpaul ryans Assessment ReflectedHis Belief About Being Pro‑American Above All Else.", "--So I believethat basedon my analysisTrump will be Successful IfHe Can ConnectwithVoters AtA Personal Level." ---Analysis:", '','''ThereAreSeveral factors which may contribute tothe success or failure OFa candidate; however,, it i important tó remember thAT these Are just predictions Based off current information AND MAY NOT REFLECT THE FUTURE.'.__.' '.___.;'[><_/_/ | __ \_____] _/) / )_/|____||----'\_______________________/'"""""`, ""')
